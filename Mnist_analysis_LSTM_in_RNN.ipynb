# %% [markdown]
# <a href="https://colab.research.google.com/github/arulperiyannagounder-collab/Training_Hands_on/blob/main/Mnist_analysis_LSTM_in_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input,LSTM,Dense
from keras.datasets import mnist

# %%
inpts=Input(shape=(28,28))
rnn_layers=LSTM(120)(inpts)
outputs=Dense(10,activation='softmax')(rnn_layers)
model = keras.Model(inputs=inpts,outputs=outputs)

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_test = x_test / 255.0
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
h=model.fit(x_train,y_train,validation_split=0.6,epochs=10)
# Out:
# Epoch 1/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.7595 - loss: 0.7167 - val_accuracy: 0.8495 - val_loss: 0.4466
# Epoch 2/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 33s 43ms/step - accuracy: 0.8698 - loss: 0.3925 - val_accuracy: 0.8765 - val_loss: 0.3695
# Epoch 3/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 33s 44ms/step - accuracy: 0.8881 - loss: 0.3302 - val_accuracy: 0.8889 - val_loss: 0.3335
# Epoch 4/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 32s 43ms/step - accuracy: 0.9042 - loss: 0.2869 - val_accuracy: 0.8928 - val_loss: 0.3160
# Epoch 5/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 31s 42ms/step - accuracy: 0.9165 - loss: 0.2491 - val_accuracy: 0.9024 - val_loss: 0.2877
# Epoch 6/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 32s 43ms/step - accuracy: 0.9195 - loss: 0.2374 - val_accuracy: 0.9086 - val_loss: 0.2807
# Epoch 7/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 31s 41ms/step - accuracy: 0.9265 - loss: 0.2159 - val_accuracy: 0.9135 - val_loss: 0.2668
# Epoch 8/10
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(h.history['accuracy'])
plt.plot(h.history['val_accuracy'])
